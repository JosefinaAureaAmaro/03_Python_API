# %% [markdown]
# ## WeatherPy
# ----
#
# #### Analysis Conclusions
# * I noticed an outlier in my Max Temp chart. While the data trended as expected, there was one city that had an opposite trend then what was expended in that range of latitude (20 - 40). Lata, India expierenced a max temp of 33 degrees Fahrenheit, which is about 20 to 15 degrees cooler than the nearby cities reviewed.
# ---
# * In regards to humidity, the same range of latitude (20-40) that had varied temperature also has the widest range of humidity than any other region. This could be due countries location in this latitude range which could be very diverse. Instead of looking at Lat and Lng sperately, spliting the world into quadrants might show more normalized results.
# ---
# * Cloudiness and Windspeed do not seem to be correlated to the latitude. Regardless of Latitide there was a consistent amount of countries with a cloudiness % that reached 100. Also, interestingly, there was 1 country that expierenced the highest windspeed out of all 500 countries reviewed, which can suggest significant weather activity.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pandas.io.json import json_normalize

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# %%
#print api_key
api_key
# Out:
# '6d4aa959ff606b95ac64b207d16eae7f'

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
city_names = []

#to reformat city names to fit in url as a complete string
for x in cities:
    
 city_reformated = x.replace(" ","_")
 city_names.append(city_reformated)
    
#to create an a list of 50 cities to call every minute
n = 50
city_sets = [city_names[i * n:(i+1)* n] for i in range((len(city_names)+ n -1)// n)]

# %%
#test sublist
city_sets[0][1]
# Out:
# 'concarneau'

# %% [markdown]
# ### Generate  Query URL

# %%
#to create a url for json requests
url = 'https://api.openweathermap.org/data/2.5/weather?q='
api_call = '&appid='+ api_key

#test url
query = url + str(city_sets[0][1]) + api_call
query
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?q=concarneau&appid=6d4aa959ff606b95ac64b207d16eae7f'

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#create an empty list to store the responses
response_weatherjson = []

print("Beginning Data Retrieval")
print('-----------------------------')

#make a request for each of the cities
for x in range(len(city_sets)):
    for j in range(len(city_sets[x])):
        try:
            print(f"Processing list set number: {x} for city {j} of 49; city name: {city_sets[x][j]}")
        except:
            print(f"City not found, skipping to next city")
            #send request
        weather_response = requests.get(url + str(city_sets[x][j]) + api_call)
            #save requests from OpenWeather Historical API
        response_weatherjson.append(weather_response.json())
            
print('---------------------------')
print("Data Retrieval Complete")
print('---------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing list set number: 0 for city 0 of 49; city name: zhuhai
# Processing list set number: 0 for city 1 of 49; city name: concarneau
# Processing list set number: 0 for city 2 of 49; city name: el_alto
# Processing list set number: 0 for city 3 of 49; city name: punta_arenas
# Processing list set number: 0 for city 4 of 49; city name: bourail
# Processing list set number: 0 for city 5 of 49; city name: mogzon
# Processing list set number: 0 for city 6 of 49; city name: vaini
# Processing list set number: 0 for city 7 of 49; city name: aklavik
# Processing list set number: 0 for city 8 of 49; city name: ushuaia
# Processing list set number: 0 for city 9 of 49; city name: yumen
# Processing list set number: 0 for city 10 of 49; city name: vao
# Processing list set number: 0 for city 11 of 49; city name: wufeng
# Processing list set number: 0 for city 12 of 49; city name: starokostyantyniv
# Processing list set number: 0 for city 13 of 49; city name: selfoss
# Processing list set number: 0 for city 14 of 49; city name: raga
# Processing list set number: 0 for city 15 of 49; city name: lasa
# Processing list set number: 0 for city 16 of 49; city name: georgetown
# Processing list set number: 0 for city 17 of 49; city name: bluff
# Processing list set number: 0 for city 18 of 49; city name: rodniki
# Processing list set number: 0 for city 19 of 49; city name: lebu
# Processing list set number: 0 for city 20 of 49; city name: albany
# Processing list set number: 0 for city 21 of 49; city name: mataura
# Processing list set number: 0 for city 22 of 49; city name: chuy
# Processing list set number: 0 for city 23 of 49; city name: puerto_ayora
# Processing list set number: 0 for city 24 of 49; city name: sao_filipe
# Processing list set number: 0 for city 25 of 49; city name: rikitea
# Processing list set number: 0 for city 26 of 49; city name: tuktoyaktuk
# Processing list set number: 0 for city 27 of 49; city name: kuhdasht
# Processing list set number: 0 for city 28 of 49; city name: busselton
# Processing list set number: 0 for city 29 of 49; city name: krasnovishersk
# Processing list set number: 0 for city 30 of 49; city name: geraldton
# Processing list set number: 0 for city 31 of 49; city name: bethel
# Processing list set number: 0 for city 32 of 49; city name: vaitupu
# Processing list set number: 0 for city 33 of 49; city name: san_patricio
# Processing list set number: 0 for city 34 of 49; city name: kichera
# Processing list set number: 0 for city 35 of 49; city name: hermanus
# Processing list set number: 0 for city 36 of 49; city name: mizdah
# Processing list set number: 0 for city 37 of 49; city name: bambous_virieux
# Processing list set number: 0 for city 38 of 49; city name: limoges
# Processing list set number: 0 for city 39 of 49; city name: vestmanna
# Processing list set number: 0 for city 40 of 49; city name: east_london
# Processing list set number: 0 for city 41 of 49; city name: taolanaro
# Processing list set number: 0 for city 42 of 49; city name: pochutla
# Processing list set number: 0 for city 43 of 49; city name: haines_junction
# Processing list set number: 0 for city 44 of 49; city name: kodiak
# Processing list set number: 0 for city 45 of 49; city name: pangnirtung
# Processing list set number: 0 for city 46 of 49; city name: atuona
# Processing list set number: 0 for city 47 of 49; city name: bermeo
# Processing list set number: 0 for city 48 of 49; city name: butaritari
# Processing list set number: 0 for city 49 of 49; city name: ribeira_grande
# Processing list set number: 1 for city 0 of 49; city name: saravan
# Processing list set number: 1 for city 1 of 49; city name: muzhi
# Processing list set number: 1 for city 2 of 49; city name: belmonte
# Processing list set number: 1 for city 3 of 49; city name: thompson
# Processing list set number: 1 for city 4 of 49; city name: seoul
# Processing list set number: 1 for city 5 of 49; city name: torbay
# Processing list set number: 1 for city 6 of 49; city name: asau
# Processing list set number: 1 for city 7 of 49; city name: nguiu
# Processing list set number: 1 for city 8 of 49; city name: castro
# Processing list set number: 1 for city 9 of 49; city name: dunedin
# Processing list set number: 1 for city 10 of 49; city name: vardo
# Processing list set number: 1 for city 11 of 49; city name: sinjar
# Processing list set number: 1 for city 12 of 49; city name: miri
# Processing list set number: 1 for city 13 of 49; city name: sur
# Processing list set number: 1 for city 14 of 49; city name: palmer
# Processing list set number: 1 for city 15 of 49; city name: ponta_delgada
# Processing list set number: 1 for city 16 of 49; city name: surt
# Processing list set number: 1 for city 17 of 49; city name: sault_sainte_marie
# Processing list set number: 1 for city 18 of 49; city name: saint-francois
# Processing list set number: 1 for city 19 of 49; city name: raudeberg
# Processing list set number: 1 for city 20 of 49; city name: ambon
# Processing list set number: 1 for city 21 of 49; city name: yulara
# Processing list set number: 1 for city 22 of 49; city name: iqaluit
# Processing list set number: 1 for city 23 of 49; city name: kangaatsiaq
# Processing list set number: 1 for city 24 of 49; city name: yokadouma
# Processing list set number: 1 for city 25 of 49; city name: illoqqortoormiut
# Processing list set number: 1 for city 26 of 49; city name: port_alfred
# Processing list set number: 1 for city 27 of 49; city name: cidreira
# Processing list set number: 1 for city 28 of 49; city name: whitecourt
# Processing list set number: 1 for city 29 of 49; city name: nanortalik
# Processing list set number: 1 for city 30 of 49; city name: iquique
# Processing list set number: 1 for city 31 of 49; city name: saint-philippe
# Processing list set number: 1 for city 32 of 49; city name: kaitangata
# Processing list set number: 1 for city 33 of 49; city name: nijar
# Processing list set number: 1 for city 34 of 49; city name: terra_santa
# Processing list set number: 1 for city 35 of 49; city name: severo-kurilsk
# Processing list set number: 1 for city 36 of 49; city name: kruisfontein
# Processing list set number: 1 for city 37 of 49; city name: nsoko
# Processing list set number: 1 for city 38 of 49; city name: carnarvon
# Processing list set number: 1 for city 39 of 49; city name: hilo
# Processing list set number: 1 for city 40 of 49; city name: lahij
# Processing list set number: 1 for city 41 of 49; city name: kapaa
# Processing list set number: 1 for city 42 of 49; city name: sola
# Processing list set number: 1 for city 43 of 49; city name: trelleborg
# Processing list set number: 1 for city 44 of 49; city name: galle
# Processing list set number: 1 for city 45 of 49; city name: new_norfolk
# Processing list set number: 1 for city 46 of 49; city name: bengkulu
# Processing list set number: 1 for city 47 of 49; city name: mar_del_plata
# Processing list set number: 1 for city 48 of 49; city name: upernavik
# Processing list set number: 1 for city 49 of 49; city name: monduli
# Processing list set number: 2 for city 0 of 49; city name: saskylakh
# Processing list set number: 2 for city 1 of 49; city name: voloiac
# Processing list set number: 2 for city 2 of 49; city name: maraa
# Processing list set number: 2 for city 3 of 49; city name: vostok
# Processing list set number: 2 for city 4 of 49; city name: khatanga
# Processing list set number: 2 for city 5 of 49; city name: atambua
# Processing list set number: 2 for city 6 of 49; city name: harper
# Processing list set number: 2 for city 7 of 49; city name: san_ramon
# Processing list set number: 2 for city 8 of 49; city name: hammerfest
# Processing list set number: 2 for city 9 of 49; city name: gidole
# Processing list set number: 2 for city 10 of 49; city name: nizhneyansk
# Processing list set number: 2 for city 11 of 49; city name: dunda
# Processing list set number: 2 for city 12 of 49; city name: nouadhibou
# Processing list set number: 2 for city 13 of 49; city name: isangel
# Processing list set number: 2 for city 14 of 49; city name: ranfurly
# Processing list set number: 2 for city 15 of 49; city name: komsomolskiy
# Processing list set number: 2 for city 16 of 49; city name: namibe
# Processing list set number: 2 for city 17 of 49; city name: hobart
# Processing list set number: 2 for city 18 of 49; city name: lorengau
# Processing list set number: 2 for city 19 of 49; city name: sinnamary
# Processing list set number: 2 for city 20 of 49; city name: faanui
# Processing list set number: 2 for city 21 of 49; city name: altamira
# Processing list set number: 2 for city 22 of 49; city name: kampot
# Processing list set number: 2 for city 23 of 49; city name: gol
# Processing list set number: 2 for city 24 of 49; city name: esperance
# Processing list set number: 2 for city 25 of 49; city name: huittinen
# Processing list set number: 2 for city 26 of 49; city name: presidencia_roque_saenz_pena
# Processing list set number: 2 for city 27 of 49; city name: hofn
# Processing list set number: 2 for city 28 of 49; city name: yellowknife
# Processing list set number: 2 for city 29 of 49; city name: meulaboh
# Processing list set number: 2 for city 30 of 49; city name: mahebourg
# Processing list set number: 2 for city 31 of 49; city name: tumannyy
# Processing list set number: 2 for city 32 of 49; city name: ozernovskiy
# Processing list set number: 2 for city 33 of 49; city name: satitoa
# Processing list set number: 2 for city 34 of 49; city name: tsihombe
# Processing list set number: 2 for city 35 of 49; city name: schifferstadt
# Processing list set number: 2 for city 36 of 49; city name: braslav
# Processing list set number: 2 for city 37 of 49; city name: lieksa
# Processing list set number: 2 for city 38 of 49; city name: tulum
# Processing list set number: 2 for city 39 of 49; city name: zhangzhou
# Processing list set number: 2 for city 40 of 49; city name: raja_jang
# Processing list set number: 2 for city 41 of 49; city name: ribas_do_rio_pardo
# Processing list set number: 2 for city 42 of 49; city name: wewak
# Processing list set number: 2 for city 43 of 49; city name: bahia_honda
# Processing list set number: 2 for city 44 of 49; city name: okha
# Processing list set number: 2 for city 45 of 49; city name: mapiripan
# Processing list set number: 2 for city 46 of 49; city name: jamestown
# Processing list set number: 2 for city 47 of 49; city name: toliary
# Processing list set number: 2 for city 48 of 49; city name: dicabisagan
# Processing list set number: 2 for city 49 of 49; city name: sangar
# Processing list set number: 3 for city 0 of 49; city name: vilhena
# Processing list set number: 3 for city 1 of 49; city name: bambanglipuro
# Processing list set number: 3 for city 2 of 49; city name: khonuu
# Processing list set number: 3 for city 3 of 49; city name: mys_shmidta
# Processing list set number: 3 for city 4 of 49; city name: mahibadhoo
# Processing list set number: 3 for city 5 of 49; city name: beyneu
# Processing list set number: 3 for city 6 of 49; city name: samalaeulu
# Processing list set number: 3 for city 7 of 49; city name: victoria
# Processing list set number: 3 for city 8 of 49; city name: cape_town
# Processing list set number: 3 for city 9 of 49; city name: clyde_river
# Processing list set number: 3 for city 10 of 49; city name: khandyga
# Processing list set number: 3 for city 11 of 49; city name: maceio
# Processing list set number: 3 for city 12 of 49; city name: nikolskoye
# Processing list set number: 3 for city 13 of 49; city name: luderitz
# Processing list set number: 3 for city 14 of 49; city name: ojinaga
# Processing list set number: 3 for city 15 of 49; city name: bredasdorp
# Processing list set number: 3 for city 16 of 49; city name: maningrida
# Processing list set number: 3 for city 17 of 49; city name: kilindoni
# Processing list set number: 3 for city 18 of 49; city name: bihariganj
# Processing list set number: 3 for city 19 of 49; city name: agadir
# Processing list set number: 3 for city 20 of 49; city name: newcastle
# Processing list set number: 3 for city 21 of 49; city name: lompoc
# Processing list set number: 3 for city 22 of 49; city name: fairbanks
# Processing list set number: 3 for city 23 of 49; city name: salme
# Processing list set number: 3 for city 24 of 49; city name: pimentel
# Processing list set number: 3 for city 25 of 49; city name: bolobo
# Processing list set number: 3 for city 26 of 49; city name: langarud
# Processing list set number: 3 for city 27 of 49; city name: biltine
# Processing list set number: 3 for city 28 of 49; city name: flinders
# Processing list set number: 3 for city 29 of 49; city name: port_elizabeth
# Processing list set number: 3 for city 30 of 49; city name: puerto_padre
# Processing list set number: 3 for city 31 of 49; city name: mosquera
# Processing list set number: 3 for city 32 of 49; city name: katsuura
# Processing list set number: 3 for city 33 of 49; city name: belushya_guba
# Processing list set number: 3 for city 34 of 49; city name: chagda
# Processing list set number: 3 for city 35 of 49; city name: nome
# Processing list set number: 3 for city 36 of 49; city name: besleney
# Processing list set number: 3 for city 37 of 49; city name: provideniya
# Processing list set number: 3 for city 38 of 49; city name: chokurdakh
# Processing list set number: 3 for city 39 of 49; city name: utiroa
# Processing list set number: 3 for city 40 of 49; city name: altay
# Processing list set number: 3 for city 41 of 49; city name: launceston
# Processing list set number: 3 for city 42 of 49; city name: kayerkan
# Processing list set number: 3 for city 43 of 49; city name: santa_maria
# Processing list set number: 3 for city 44 of 49; city name: saint_george
# Processing list set number: 3 for city 45 of 49; city name: narsaq
# Processing list set number: 3 for city 46 of 49; city name: colchester
# Processing list set number: 3 for city 47 of 49; city name: puerto_ayacucho
# Processing list set number: 3 for city 48 of 49; city name: anadyr
# Processing list set number: 3 for city 49 of 49; city name: moose_jaw
# Processing list set number: 4 for city 0 of 49; city name: salalah
# Processing list set number: 4 for city 1 of 49; city name: olafsvik
# Processing list set number: 4 for city 2 of 49; city name: poum
# Processing list set number: 4 for city 3 of 49; city name: coquimbo
# Processing list set number: 4 for city 4 of 49; city name: meyungs
# Processing list set number: 4 for city 5 of 49; city name: attawapiskat
# Processing list set number: 4 for city 6 of 49; city name: veraval
# Processing list set number: 4 for city 7 of 49; city name: mahanoro
# Processing list set number: 4 for city 8 of 49; city name: springdale
# Processing list set number: 4 for city 9 of 49; city name: vestmannaeyjar
# Processing list set number: 4 for city 10 of 49; city name: stornoway
# Processing list set number: 4 for city 11 of 49; city name: inuvik
# Processing list set number: 4 for city 12 of 49; city name: grand_river_south_east
# Processing list set number: 4 for city 13 of 49; city name: shingu
# Processing list set number: 4 for city 14 of 49; city name: tasiilaq
# Processing list set number: 4 for city 15 of 49; city name: beidao
# Processing list set number: 4 for city 16 of 49; city name: bandarbeyla
# Processing list set number: 4 for city 17 of 49; city name: tamandare
# Processing list set number: 4 for city 18 of 49; city name: yeppoon
# Processing list set number: 4 for city 19 of 49; city name: amderma
# Processing list set number: 4 for city 20 of 49; city name: avarua
# Processing list set number: 4 for city 21 of 49; city name: deh_rawud
# Processing list set number: 4 for city 22 of 49; city name: mount_gambier
# Processing list set number: 4 for city 23 of 49; city name: dodge_city
# Processing list set number: 4 for city 24 of 49; city name: hay_river
# Processing list set number: 4 for city 25 of 49; city name: port_lincoln
# Processing list set number: 4 for city 26 of 49; city name: alto_piquiri
# Processing list set number: 4 for city 27 of 49; city name: denpasar
# Processing list set number: 4 for city 28 of 49; city name: paamiut
# Processing list set number: 4 for city 29 of 49; city name: bairiki
# Processing list set number: 4 for city 30 of 49; city name: fairview
# Processing list set number: 4 for city 31 of 49; city name: umm_kaddadah
# Processing list set number: 4 for city 32 of 49; city name: tiksi
# Processing list set number: 4 for city 33 of 49; city name: naze
# Processing list set number: 4 for city 34 of 49; city name: bathsheba
# Processing list set number: 4 for city 35 of 49; city name: chicama
# Processing list set number: 4 for city 36 of 49; city name: maniwaki
# Processing list set number: 4 for city 37 of 49; city name: ketchikan
# Processing list set number: 4 for city 38 of 49; city name: malko_tarnovo
# Processing list set number: 4 for city 39 of 49; city name: asfi
# Processing list set number: 4 for city 40 of 49; city name: dalvik
# Processing list set number: 4 for city 41 of 49; city name: barentsburg
# Processing list set number: 4 for city 42 of 49; city name: matara
# Processing list set number: 4 for city 43 of 49; city name: arraial_do_cabo
# Processing list set number: 4 for city 44 of 49; city name: price
# Processing list set number: 4 for city 45 of 49; city name: palu
# Processing list set number: 4 for city 46 of 49; city name: cherskiy
# Processing list set number: 4 for city 47 of 49; city name: wajima
# Processing list set number: 4 for city 48 of 49; city name: alofi
# Processing list set number: 4 for city 49 of 49; city name: nerja
# Processing list set number: 5 for city 0 of 49; city name: ponta_do_sol
# Processing list set number: 5 for city 1 of 49; city name: ilulissat
# Processing list set number: 5 for city 2 of 49; city name: ostrovnoy
# Processing list set number: 5 for city 3 of 49; city name: magnitogorsk
# Processing list set number: 5 for city 4 of 49; city name: sakakah
# Processing list set number: 5 for city 5 of 49; city name: longyearbyen
# Processing list set number: 5 for city 6 of 49; city name: nikolayevka
# Processing list set number: 5 for city 7 of 49; city name: hithadhoo
# Processing list set number: 5 for city 8 of 49; city name: robertsport
# Processing list set number: 5 for city 9 of 49; city name: general_pico
# Processing list set number: 5 for city 10 of 49; city name: namanyere
# Processing list set number: 5 for city 11 of 49; city name: yar-sale
# Processing list set number: 5 for city 12 of 49; city name: umzimvubu
# Processing list set number: 5 for city 13 of 49; city name: gap
# Processing list set number: 5 for city 14 of 49; city name: samarai
# Processing list set number: 5 for city 15 of 49; city name: caala
# Processing list set number: 5 for city 16 of 49; city name: grand_gaube
# Processing list set number: 5 for city 17 of 49; city name: santa_cruz_cabralia
# Processing list set number: 5 for city 18 of 49; city name: xuddur
# Processing list set number: 5 for city 19 of 49; city name: fortuna
# Processing list set number: 5 for city 20 of 49; city name: uvaly
# Processing list set number: 5 for city 21 of 49; city name: inzer
# Processing list set number: 5 for city 22 of 49; city name: dikson
# Processing list set number: 5 for city 23 of 49; city name: dalby
# Processing list set number: 5 for city 24 of 49; city name: tankhoy
# Processing list set number: 5 for city 25 of 49; city name: zatoka
# Processing list set number: 5 for city 26 of 49; city name: hami
# Processing list set number: 5 for city 27 of 49; city name: bonthe
# Processing list set number: 5 for city 28 of 49; city name: pontes_e_lacerda
# Processing list set number: 5 for city 29 of 49; city name: zhigansk
# Processing list set number: 5 for city 30 of 49; city name: faya
# Processing list set number: 5 for city 31 of 49; city name: batagay
# Processing list set number: 5 for city 32 of 49; city name: kawalu
# Processing list set number: 5 for city 33 of 49; city name: tra_vinh
# Processing list set number: 5 for city 34 of 49; city name: lagoa
# Processing list set number: 5 for city 35 of 49; city name: pitea
# Processing list set number: 5 for city 36 of 49; city name: lethem
# Processing list set number: 5 for city 37 of 49; city name: qaanaaq
# Processing list set number: 5 for city 38 of 49; city name: nemuro
# Processing list set number: 5 for city 39 of 49; city name: dingli
# Processing list set number: 5 for city 40 of 49; city name: sentyabrskiy
# Processing list set number: 5 for city 41 of 49; city name: hazleton
# Processing list set number: 5 for city 42 of 49; city name: pevek
# Processing list set number: 5 for city 43 of 49; city name: quang_ngai
# Processing list set number: 5 for city 44 of 49; city name: jertih
# Processing list set number: 5 for city 45 of 49; city name: sitka
# Processing list set number: 5 for city 46 of 49; city name: barrow
# Processing list set number: 5 for city 47 of 49; city name: sotouboua
# Processing list set number: 5 for city 48 of 49; city name: izhma
# Processing list set number: 5 for city 49 of 49; city name: mahon
# Processing list set number: 6 for city 0 of 49; city name: emba
# Processing list set number: 6 for city 1 of 49; city name: cabo_san_lucas
# Processing list set number: 6 for city 2 of 49; city name: vila_velha
# Processing list set number: 6 for city 3 of 49; city name: norman_wells
# Processing list set number: 6 for city 4 of 49; city name: axim
# Processing list set number: 6 for city 5 of 49; city name: almeirim
# Processing list set number: 6 for city 6 of 49; city name: juazeiro
# Processing list set number: 6 for city 7 of 49; city name: lolua
# Processing list set number: 6 for city 8 of 49; city name: yerbogachen
# Processing list set number: 6 for city 9 of 49; city name: bulalacao
# Processing list set number: 6 for city 10 of 49; city name: marcona
# Processing list set number: 6 for city 11 of 49; city name: huadian
# Processing list set number: 6 for city 12 of 49; city name: vohma
# Processing list set number: 6 for city 13 of 49; city name: yuci
# Processing list set number: 6 for city 14 of 49; city name: kulhudhuffushi
# Processing list set number: 6 for city 15 of 49; city name: honiara
# Processing list set number: 6 for city 16 of 49; city name: umm_lajj
# Processing list set number: 6 for city 17 of 49; city name: praia_da_vitoria
# Processing list set number: 6 for city 18 of 49; city name: isabela
# Processing list set number: 6 for city 19 of 49; city name: mayumba
# Processing list set number: 6 for city 20 of 49; city name: kirakira
# Processing list set number: 6 for city 21 of 49; city name: katav-ivanovsk
# Processing list set number: 6 for city 22 of 49; city name: gulaothi
# Processing list set number: 6 for city 23 of 49; city name: sao_joao_da_barra
# Processing list set number: 6 for city 24 of 49; city name: portland
# Processing list set number: 6 for city 25 of 49; city name: kloulklubed
# Processing list set number: 6 for city 26 of 49; city name: bay_roberts
# Processing list set number: 6 for city 27 of 49; city name: duz
# Processing list set number: 6 for city 28 of 49; city name: northam
# Processing list set number: 6 for city 29 of 49; city name: kavaratti
# Processing list set number: 6 for city 30 of 49; city name: hulan
# Processing list set number: 6 for city 31 of 49; city name: hohhot
# Processing list set number: 6 for city 32 of 49; city name: alotau
# Processing list set number: 6 for city 33 of 49; city name: cayenne
# Processing list set number: 6 for city 34 of 49; city name: venado_tuerto
# Processing list set number: 6 for city 35 of 49; city name: plettenberg_bay
# Processing list set number: 6 for city 36 of 49; city name: souillac
# Processing list set number: 6 for city 37 of 49; city name: santa_fe
# Processing list set number: 6 for city 38 of 49; city name: demirci
# Processing list set number: 6 for city 39 of 49; city name: zanjan
# Processing list set number: 6 for city 40 of 49; city name: darnah
# Processing list set number: 6 for city 41 of 49; city name: shenjiamen
# Processing list set number: 6 for city 42 of 49; city name: ahipara
# Processing list set number: 6 for city 43 of 49; city name: tuatapere
# Processing list set number: 6 for city 44 of 49; city name: tiarei
# Processing list set number: 6 for city 45 of 49; city name: samusu
# Processing list set number: 6 for city 46 of 49; city name: kodinsk
# Processing list set number: 6 for city 47 of 49; city name: kikwit
# Processing list set number: 6 for city 48 of 49; city name: kismayo
# Processing list set number: 6 for city 49 of 49; city name: tura
# Processing list set number: 7 for city 0 of 49; city name: masvingo
# Processing list set number: 7 for city 1 of 49; city name: akyab
# Processing list set number: 7 for city 2 of 49; city name: biloela
# Processing list set number: 7 for city 3 of 49; city name: soure
# Processing list set number: 7 for city 4 of 49; city name: soyo
# Processing list set number: 7 for city 5 of 49; city name: christchurch
# Processing list set number: 7 for city 6 of 49; city name: mehamn
# Processing list set number: 7 for city 7 of 49; city name: san_lorenzo
# Processing list set number: 7 for city 8 of 49; city name: malwan
# Processing list set number: 7 for city 9 of 49; city name: byron_bay
# Processing list set number: 7 for city 10 of 49; city name: kavieng
# Processing list set number: 7 for city 11 of 49; city name: port_macquarie
# Processing list set number: 7 for city 12 of 49; city name: huaiyuan
# Processing list set number: 7 for city 13 of 49; city name: mutoko
# Processing list set number: 7 for city 14 of 49; city name: touros
# Processing list set number: 7 for city 15 of 49; city name: wakkanai
# Processing list set number: 7 for city 16 of 49; city name: yemtsa
# Processing list set number: 7 for city 17 of 49; city name: rangapara
# Processing list set number: 7 for city 18 of 49; city name: rio_verde_de_mato_grosso
# Processing list set number: 7 for city 19 of 49; city name: goderich
# Processing list set number: 7 for city 20 of 49; city name: fort_saint_john
# Processing list set number: 7 for city 21 of 49; city name: guider
# Processing list set number: 7 for city 22 of 49; city name: pokrovka
# Processing list set number: 7 for city 23 of 49; city name: nalut
# Processing list set number: 7 for city 24 of 49; city name: saint_anthony
# Processing list set number: 7 for city 25 of 49; city name: airai
# Processing list set number: 7 for city 26 of 49; city name: san_cristobal
# Processing list set number: 7 for city 27 of 49; city name: mersing
# Processing list set number: 7 for city 28 of 49; city name: ulaangom
# Processing list set number: 7 for city 29 of 49; city name: ozark
# Processing list set number: 7 for city 30 of 49; city name: moron
# Processing list set number: 7 for city 31 of 49; city name: mecca
# Processing list set number: 7 for city 32 of 49; city name: comodoro_rivadavia
# Processing list set number: 7 for city 33 of 49; city name: colquiri
# Processing list set number: 7 for city 34 of 49; city name: quarai
# Processing list set number: 7 for city 35 of 49; city name: truth_or_consequences
# Processing list set number: 7 for city 36 of 49; city name: kenai
# Processing list set number: 7 for city 37 of 49; city name: otukpo
# Processing list set number: 7 for city 38 of 49; city name: hamilton
# Processing list set number: 7 for city 39 of 49; city name: killybegs
# Processing list set number: 7 for city 40 of 49; city name: khuzhir
# Processing list set number: 7 for city 41 of 49; city name: ust-kuyga
# Processing list set number: 7 for city 42 of 49; city name: zhanaozen
# Processing list set number: 7 for city 43 of 49; city name: mrakovo
# Processing list set number: 7 for city 44 of 49; city name: caravelas
# Processing list set number: 7 for city 45 of 49; city name: gunjur
# Processing list set number: 7 for city 46 of 49; city name: talara
# Processing list set number: 7 for city 47 of 49; city name: manggar
# Processing list set number: 7 for city 48 of 49; city name: tirano
# Processing list set number: 7 for city 49 of 49; city name: saint-pierre
# Processing list set number: 8 for city 0 of 49; city name: jalu
# Processing list set number: 8 for city 1 of 49; city name: san_quintin
# Processing list set number: 8 for city 2 of 49; city name: bargal
# Processing list set number: 8 for city 3 of 49; city name: ossora
# Processing list set number: 8 for city 4 of 49; city name: ulladulla
# Processing list set number: 8 for city 5 of 49; city name: piacabucu
# Processing list set number: 8 for city 6 of 49; city name: itacurubi_de_la_cordillera
# Processing list set number: 8 for city 7 of 49; city name: kroya
# Processing list set number: 8 for city 8 of 49; city name: pacific_grove
# Processing list set number: 8 for city 9 of 49; city name: twin_falls
# Processing list set number: 8 for city 10 of 49; city name: porto_santo
# Processing list set number: 8 for city 11 of 49; city name: nuuk
# Processing list set number: 8 for city 12 of 49; city name: andra
# Processing list set number: 8 for city 13 of 49; city name: vanimo
# Processing list set number: 8 for city 14 of 49; city name: pisco
# Processing list set number: 8 for city 15 of 49; city name: kathmandu
# Processing list set number: 8 for city 16 of 49; city name: aksarayskiy
# Processing list set number: 8 for city 17 of 49; city name: watsa
# Processing list set number: 8 for city 18 of 49; city name: wum
# Processing list set number: 8 for city 19 of 49; city name: hun
# Processing list set number: 8 for city 20 of 49; city name: hasaki
# Processing list set number: 8 for city 21 of 49; city name: saleaula
# Processing list set number: 8 for city 22 of 49; city name: dakoro
# Processing list set number: 8 for city 23 of 49; city name: phalaborwa
# Processing list set number: 8 for city 24 of 49; city name: barawe
# Processing list set number: 8 for city 25 of 49; city name: mangan
# Processing list set number: 8 for city 26 of 49; city name: novobirilyussy
# Processing list set number: 8 for city 27 of 49; city name: saldanha
# Processing list set number: 8 for city 28 of 49; city name: aksarka
# Processing list set number: 8 for city 29 of 49; city name: khor
# Processing list set number: 8 for city 30 of 49; city name: port_hardy
# Processing list set number: 8 for city 31 of 49; city name: avera
# Processing list set number: 8 for city 32 of 49; city name: lakewood
# Processing list set number: 8 for city 33 of 49; city name: klyuchi
# Processing list set number: 8 for city 34 of 49; city name: constitucion
# Processing list set number: 8 for city 35 of 49; city name: kibondo
# Processing list set number: 8 for city 36 of 49; city name: dingle
# Processing list set number: 8 for city 37 of 49; city name: bilibino
# Processing list set number: 8 for city 38 of 49; city name: kulachi
# Processing list set number: 8 for city 39 of 49; city name: derzhavinsk
# Processing list set number: 8 for city 40 of 49; city name: rurrenabaque
# Processing list set number: 8 for city 41 of 49; city name: swellendam
# Processing list set number: 8 for city 42 of 49; city name: itarema
# Processing list set number: 8 for city 43 of 49; city name: luneville
# Processing list set number: 8 for city 44 of 49; city name: sigli
# Processing list set number: 8 for city 45 of 49; city name: lavrentiya
# Processing list set number: 8 for city 46 of 49; city name: moose_factory
# Processing list set number: 8 for city 47 of 49; city name: ayan
# Processing list set number: 8 for city 48 of 49; city name: mitzic
# Processing list set number: 8 for city 49 of 49; city name: wladyslawowo
# Processing list set number: 9 for city 0 of 49; city name: kyra
# Processing list set number: 9 for city 1 of 49; city name: virginia_beach
# Processing list set number: 9 for city 2 of 49; city name: beringovskiy
# Processing list set number: 9 for city 3 of 49; city name: epe
# Processing list set number: 9 for city 4 of 49; city name: kaoma
# Processing list set number: 9 for city 5 of 49; city name: ijaki
# Processing list set number: 9 for city 6 of 49; city name: turan
# Processing list set number: 9 for city 7 of 49; city name: leesburg
# Processing list set number: 9 for city 8 of 49; city name: manzhouli
# Processing list set number: 9 for city 9 of 49; city name: imbituba
# Processing list set number: 9 for city 10 of 49; city name: jinchang
# Processing list set number: 9 for city 11 of 49; city name: pyay
# Processing list set number: 9 for city 12 of 49; city name: doctor_pedro_p._pena
# Processing list set number: 9 for city 13 of 49; city name: manaus
# Processing list set number: 9 for city 14 of 49; city name: zavetnoye
# Processing list set number: 9 for city 15 of 49; city name: ancud
# Processing list set number: 9 for city 16 of 49; city name: aasiaat
# Processing list set number: 9 for city 17 of 49; city name: codajas
# Processing list set number: 9 for city 18 of 49; city name: waddan
# Processing list set number: 9 for city 19 of 49; city name: leningradskiy
# Processing list set number: 9 for city 20 of 49; city name: chapais
# Processing list set number: 9 for city 21 of 49; city name: kahului
# Processing list set number: 9 for city 22 of 49; city name: bako
# Processing list set number: 9 for city 23 of 49; city name: bam
# Processing list set number: 9 for city 24 of 49; city name: krasnoarmeysk
# Processing list set number: 9 for city 25 of 49; city name: talnakh
# Processing list set number: 9 for city 26 of 49; city name: kitami
# Processing list set number: 9 for city 27 of 49; city name: daxian
# Processing list set number: 9 for city 28 of 49; city name: carson_city
# Processing list set number: 9 for city 29 of 49; city name: russell
# Processing list set number: 9 for city 30 of 49; city name: rio_grande
# Processing list set number: 9 for city 31 of 49; city name: winnipeg
# Processing list set number: 9 for city 32 of 49; city name: mangrol
# Processing list set number: 9 for city 33 of 49; city name: tabou
# Processing list set number: 9 for city 34 of 49; city name: kumluca
# Processing list set number: 9 for city 35 of 49; city name: gemunden
# Processing list set number: 9 for city 36 of 49; city name: talcahuano
# Processing list set number: 9 for city 37 of 49; city name: zyryanka
# Processing list set number: 9 for city 38 of 49; city name: henties_bay
# Processing list set number: 9 for city 39 of 49; city name: chumphon
# Processing list set number: 9 for city 40 of 49; city name: fort_frances
# Processing list set number: 9 for city 41 of 49; city name: barcelos
# Processing list set number: 9 for city 42 of 49; city name: valdez
# Processing list set number: 9 for city 43 of 49; city name: tucuman
# Processing list set number: 9 for city 44 of 49; city name: nikolayevsk-na-amure
# Processing list set number: 9 for city 45 of 49; city name: dronten
# Processing list set number: 9 for city 46 of 49; city name: gourdon
# Processing list set number: 9 for city 47 of 49; city name: palabuhanratu
# Processing list set number: 9 for city 48 of 49; city name: vanavara
# Processing list set number: 9 for city 49 of 49; city name: manta
# Processing list set number: 10 for city 0 of 49; city name: bend
# Processing list set number: 10 for city 1 of 49; city name: kamenskoye
# Processing list set number: 10 for city 2 of 49; city name: korla
# Processing list set number: 10 for city 3 of 49; city name: ukiah
# Processing list set number: 10 for city 4 of 49; city name: terney
# Processing list set number: 10 for city 5 of 49; city name: half_moon_bay
# Processing list set number: 10 for city 6 of 49; city name: zaozerne
# Processing list set number: 10 for city 7 of 49; city name: labuhan
# Processing list set number: 10 for city 8 of 49; city name: vicar
# Processing list set number: 10 for city 9 of 49; city name: berlevag
# Processing list set number: 10 for city 10 of 49; city name: ksenyevka
# Processing list set number: 10 for city 11 of 49; city name: riyadh
# Processing list set number: 10 for city 12 of 49; city name: tevriz
# Processing list set number: 10 for city 13 of 49; city name: necochea
# Processing list set number: 10 for city 14 of 49; city name: karaton
# Processing list set number: 10 for city 15 of 49; city name: marawi
# Processing list set number: 10 for city 16 of 49; city name: progreso
# Processing list set number: 10 for city 17 of 49; city name: lannion
# Processing list set number: 10 for city 18 of 49; city name: coracora
# Processing list set number: 10 for city 19 of 49; city name: chabahar
# Processing list set number: 10 for city 20 of 49; city name: den_helder
# Processing list set number: 10 for city 21 of 49; city name: yangjiang
# Processing list set number: 10 for city 22 of 49; city name: valparaiso
# Processing list set number: 10 for city 23 of 49; city name: huilong
# Processing list set number: 10 for city 24 of 49; city name: guerrero_negro
# Processing list set number: 10 for city 25 of 49; city name: alta_floresta
# Processing list set number: 10 for city 26 of 49; city name: champerico
# Processing list set number: 10 for city 27 of 49; city name: porto_walter
# Processing list set number: 10 for city 28 of 49; city name: richards_bay
# Processing list set number: 10 for city 29 of 49; city name: klaksvik
# Processing list set number: 10 for city 30 of 49; city name: booue
# Processing list set number: 10 for city 31 of 49; city name: empangeni
# Processing list set number: 10 for city 32 of 49; city name: road_town
# Processing list set number: 10 for city 33 of 49; city name: terekli-mekteb
# Processing list set number: 10 for city 34 of 49; city name: najran
# Processing list set number: 10 for city 35 of 49; city name: tessalit
# Processing list set number: 10 for city 36 of 49; city name: abilene
# Processing list set number: 10 for city 37 of 49; city name: cehegin
# Processing list set number: 10 for city 38 of 49; city name: neryungri
# Processing list set number: 10 for city 39 of 49; city name: eirunepe
# Processing list set number: 10 for city 40 of 49; city name: sungaipenuh
# Processing list set number: 10 for city 41 of 49; city name: husavik
# Processing list set number: 10 for city 42 of 49; city name: codrington
# Processing list set number: 10 for city 43 of 49; city name: oranjestad
# Processing list set number: 10 for city 44 of 49; city name: kazalinsk
# Processing list set number: 10 for city 45 of 49; city name: marsa_matruh
# Processing list set number: 10 for city 46 of 49; city name: los_llanos_de_aridane
# Processing list set number: 10 for city 47 of 49; city name: nurota
# Processing list set number: 10 for city 48 of 49; city name: sioux_lookout
# Processing list set number: 10 for city 49 of 49; city name: tromso
# Processing list set number: 11 for city 0 of 49; city name: kirovskiy
# Processing list set number: 11 for city 1 of 49; city name: makakilo_city
# Processing list set number: 11 for city 2 of 49; city name: ust-kulom
# Processing list set number: 11 for city 3 of 49; city name: allingabro
# Processing list set number: 11 for city 4 of 49; city name: port_blair
# Processing list set number: 11 for city 5 of 49; city name: rancho_palos_verdes
# Processing list set number: 11 for city 6 of 49; city name: halalo
# Processing list set number: 11 for city 7 of 49; city name: bonfim
# Processing list set number: 11 for city 8 of 49; city name: hovd
# Processing list set number: 11 for city 9 of 49; city name: honningsvag
# Processing list set number: 11 for city 10 of 49; city name: candawaga
# Processing list set number: 11 for city 11 of 49; city name: camopi
# Processing list set number: 11 for city 12 of 49; city name: revda
# Processing list set number: 11 for city 13 of 49; city name: hirara
# Processing list set number: 11 for city 14 of 49; city name: qandala
# Processing list set number: 11 for city 15 of 49; city name: yaan
# Processing list set number: 11 for city 16 of 49; city name: kerewan
# Processing list set number: 11 for city 17 of 49; city name: batemans_bay
# Processing list set number: 11 for city 18 of 49; city name: sao_paulo_de_olivenca
# Processing list set number: 11 for city 19 of 49; city name: novaya_bryan
# Processing list set number: 11 for city 20 of 49; city name: mantua
# Processing list set number: 11 for city 21 of 49; city name: koslan
# Processing list set number: 11 for city 22 of 49; city name: nokaneng
# Processing list set number: 11 for city 23 of 49; city name: mabaruma
# Processing list set number: 11 for city 24 of 49; city name: mokokchung
# Processing list set number: 11 for city 25 of 49; city name: okakarara
# Processing list set number: 11 for city 26 of 49; city name: konevo
# Processing list set number: 11 for city 27 of 49; city name: hualmay
# Processing list set number: 11 for city 28 of 49; city name: kushmurun
# Processing list set number: 11 for city 29 of 49; city name: lyuban
# Processing list set number: 11 for city 30 of 49; city name: san_lawrenz
# Processing list set number: 11 for city 31 of 49; city name: petropavlovsk-kamchatskiy
# Processing list set number: 11 for city 32 of 49; city name: boddam
# Processing list set number: 11 for city 33 of 49; city name: kachug
# Processing list set number: 11 for city 34 of 49; city name: avigliana
# Processing list set number: 11 for city 35 of 49; city name: koundara
# Processing list set number: 11 for city 36 of 49; city name: college
# Processing list set number: 11 for city 37 of 49; city name: mennecy
# Processing list set number: 11 for city 38 of 49; city name: havoysund
# Processing list set number: 11 for city 39 of 49; city name: omsukchan
# Processing list set number: 11 for city 40 of 49; city name: betzdorf
# Processing list set number: 11 for city 41 of 49; city name: mount_isa
# Processing list set number: 11 for city 42 of 49; city name: mbinga
# Processing list set number: 11 for city 43 of 49; city name: kaeo
# Processing list set number: 11 for city 44 of 49; city name: cockburn_town
# Processing list set number: 11 for city 45 of 49; city name: vikhorevka
# Processing list set number: 11 for city 46 of 49; city name: nichinan
# Processing list set number: 11 for city 47 of 49; city name: kitakata
# Processing list set number: 11 for city 48 of 49; city name: bilma
# Processing list set number: 11 for city 49 of 49; city name: methoni
# Processing list set number: 12 for city 0 of 49; city name: turka
# Processing list set number: 12 for city 1 of 49; city name: garm
# Processing list set number: 12 for city 2 of 49; city name: bulgan
# Processing list set number: 12 for city 3 of 49; city name: cervo
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
#print how many requests we have
print(f"We have {len(response_weatherjson)} cities weather data!")
# Out:
# We have 604 cities weather data!

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#to make sure json call didn't produce an error
response_weatherjson[1]
# Out:
# {'coord': {'lon': -3.92, 'lat': 47.88},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 282.49,
#   'pressure': 990,
#   'humidity': 93,
#   'temp_min': 279.82,
#   'temp_max': 285.37},
#  'visibility': 10000,
#  'wind': {'speed': 4.6, 'deg': 260},
#  'rain': {'3h': 1.69},
#  'clouds': {'all': 91},
#  'dt': 1572899365,
#  'sys': {'type': 1,
#   'id': 6568,
#   'country': 'FR',
#   'sunrise': 1572851053,
#   'sunset': 1572886453},
#  'timezone': 3600,
#  'id': 3024035,
#  'name': 'Concarneau',
#  'cod': 200}

# %%
#normalize nest columns in json data

df = pd.DataFrame.from_dict(json_normalize(response_weatherjson), orient= 'columns')
df_1 = df.drop(['weather','base','main.pressure','main.temp_min','main.grnd_level','main.sea_level','main.temp','visibility','wind.deg','sys.id','sys.sunrise','sys.sunset','timezone','id','cod','message','rain.1h','rain.3h','sys.type','wind.gust'], axis=1)

# %%
df_2 = df_1.rename(columns = {'name':'City',
                              'clouds.all':'Cloudiness',
                              'coord.lat':'Lat',
                              'coord.lon':'Lng',
                              'dt':'Date',
                              'main.humidity':'Humidity',
                              'main.temp_max':'Max Temp',
                              'sys.country':'Country',
                              'wind.speed':'Wind Speed'
                             })

# %%
df_final= df_2.dropna(axis=0, subset=['City'])
df_final.head()
# Out:
#            Date        City     Lng    Lat  Humidity  Max Temp  Wind Speed  \
# 0  1.572899e+09      Zhuhai  112.04  40.71      80.0    272.15        2.00
# 1  1.572899e+09  Concarneau   -3.92  47.88      93.0    285.37        4.60
# 4  1.572899e+09     Bourail  165.50 -21.57      60.0    296.24        2.68
# 5  1.572899e+09      Mogzon  111.97  51.74      62.0    263.83        1.25
# 6  1.572899e+09       Vaini   74.49  15.34      90.0    294.26        0.70
#
#    Cloudiness Country  snow.3h
# 0         1.0      CN      NaN
# 1        91.0      FR      NaN
# 4        36.0      NC      NaN
# 5        93.0      RU      NaN
# 6        86.0      IN      NaN

# %%
#convert max temp to degree fahrenheit
df_final['Max Temp'] = ((df_final['Max Temp']-273)+32).round(0)
df_export = df_final.dropna(axis='columns')

# %%
df_export.count()
# Out:
# Date          455
# City          455
# Lng           455
# Lat           455
# Humidity      455
# Max Temp      455
# Wind Speed    455
# Cloudiness    455
# Country       455
# dtype: int64

# %%
df_export.head()
# Out:
#            Date        City     Lng    Lat  Humidity  Max Temp  Wind Speed  \
# 0  1.572899e+09      Zhuhai  112.04  40.71      80.0      31.0        2.00
# 1  1.572899e+09  Concarneau   -3.92  47.88      93.0      44.0        4.60
# 4  1.572899e+09     Bourail  165.50 -21.57      60.0      55.0        2.68
# 5  1.572899e+09      Mogzon  111.97  51.74      62.0      23.0        1.25
# 6  1.572899e+09       Vaini   74.49  15.34      90.0      53.0        0.70
#
#    Cloudiness Country
# 0         1.0      CN
# 1        91.0      FR
# 4        36.0      NC
# 5        93.0      RU
# 6        86.0      IN

# %%
output_data_file = "./resources/cities.csv"
df_export.to_csv(output_data_file, sep=',', encoding= 'utf-8', index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df_export.head()
# Out:
#            Date        City     Lng    Lat  Humidity  Max Temp  Wind Speed  \
# 0  1.572899e+09      Zhuhai  112.04  40.71      80.0      31.0        2.00
# 1  1.572899e+09  Concarneau   -3.92  47.88      93.0      44.0        4.60
# 4  1.572899e+09     Bourail  165.50 -21.57      60.0      55.0        2.68
# 5  1.572899e+09      Mogzon  111.97  51.74      62.0      23.0        1.25
# 6  1.572899e+09       Vaini   74.49  15.34      90.0      53.0        0.70
#
#    Cloudiness Country
# 0         1.0      CN
# 1        91.0      FR
# 4        36.0      NC
# 5        93.0      RU
# 6        86.0      IN

# %%
## assign x_axis throughout 
X_axis = df_export["Lat"]

# %%
#set y axis
temp_y_axis = df_export["Max Temp"]

# %%
# Generate the scatter plot
    
ax = plt.scatter(X_axis,temp_y_axis, marker ="o",edgecolors='black')

#assign axis labels and grid lines
plt.grid(True)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.title('City Latitude vs. Max Temperature (6/16/2019)')

#format plot
ax.use_sticky_edges = False


# Save the Figure
plt.savefig('./charts/City_Latitude_vs_Temp.png',dpi=150, bbox_inches = 'tight')
plt.show()

# %%
#observation analysis
max_temp = df_export[(df_export["Lat"] >= 20) & (df_export["Lat"] <= 40)]

# %%
max_temp.loc[max_temp['Max Temp'] == max_temp['Max Temp'].min()]
# Out:
#              Date  City   Lng    Lat  Humidity  Max Temp  Wind Speed  \
# 447  1.572899e+09  Ayan  44.7  38.23      57.0      33.0        0.57
#
#      Cloudiness Country
# 447         4.0      IR

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#set y axis
hum_y_axis = df_export["Humidity"]

# %%
# Generate the scatter plot
    
ax = plt.scatter(X_axis, hum_y_axis, marker ="o",edgecolors='black')

#assign axis labels and grid lines
plt.grid(True)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.title('City Latitude vs. Humidity (6/16/2019)')

#format plot
ax.use_sticky_edges = False


# Save the Figure
plt.savefig('./charts/City_Latitude_vs_Hum.png',dpi=150, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#set y axis
clouds_y_axis = df_export["Cloudiness"]

# %%
# Generate the scatter plot
    
ax = plt.scatter(X_axis,clouds_y_axis, marker ="o",edgecolors='black')

#assign axis labels and grid lines
plt.grid(True)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.title('City Latitude vs. Cloudiness (6/16/2019)')

#format plot
ax.use_sticky_edges = False


# Save the Figure
plt.savefig('./charts/City_Latitude_vs_Clouds.png',dpi=150, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#set y axis
winds_y_axis = df_final['Wind Speed']

# %%
# Generate the scatter plot
    
ax = plt.scatter(X_axis,winds_y_axis, marker ="o",edgecolors='black')

#assign axis labels and grid lines
plt.grid(True)
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.title('City Latitude vs. Wind Speed (6/16/2019)')

#format plot
ax.use_sticky_edges = False


# Save the Figure
plt.savefig('./charts/City_Latitude_vs_Wind.png',dpi=150, bbox_inches = 'tight')
plt.show()
